# %% [markdown]
# <a href="https://colab.research.google.com/github/udaykiranreddykondreddy/Code-for-learn-machinelearning/blob/master/autoencoders/Autoencoder_CNN_autoencoder.ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1xZggtEjnrMp9QBm_4q5RJIfJyfSoSJ9p" height="150" align="left"/>
# <h1>&nbsp;<a href="https://instagram.com/learn.machinelearning">Learn.MachineLearning</a></h1>
# <h2>&nbsp;AutoEncoders</h2>
# <h2>&nbsp;Deep Autoencoders, Convolutional autoencoder</h2>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1vG1zdxXrp7Yp5naC8PgMl5UlpXXjou9Z" height="500"/>
#
# **<h3>What is Autoencoder??</h3>**
#
# - It is an unsupervised learning neural network
# - It tries to ReGenerate the input
# - It has 2 components Encoder and Decoder

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1UuRc-yEc-YGAlEa8RHqp3V2z3-uANlpA" height="500"/>
#
# **<h3>What is Encoder??</h3>**
#
# - Aim of encoder is to compress the data
# - It tries to find the function that maps input data (X) to compressed data (H)
# \begin{equation} H  = f(X) \end{equation}

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1QHtS0GxdfbGf3GId-4PjK_YhElF7PljE" height="500"/>
#
# **<h3>What is Latent Vector??</h3>**
#
#  - It is a learned representation of input data in a low dimension space.

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1qTkQx76aBJNhsk3ITrUBEfDQzDQtzMc0" height="500"/>
#
#
# **<h3>What is Decoder??</h3>**
#
# - It tries to reconstruct the input from latent vector
# - It also try to find the function that maps the latent vector to reconstructed data
# \begin{equation} \hat{{X}}  = g(H) \end{equation}
#
# <img src="http://drive.google.com/uc?export=view&id=1kHLR8RgP2Ci8u0LGz5pHlhxBbz7n0E_y" height="500"/>
#
#
# - So final equation can be written as
# \begin{equation} \hat{{X}}  = g(f(X)) \end{equation}

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=15zm2U3EaH4UkKm04GXB_sSZGaUPevBgz" height="500"/>
#
# **<h3>Calculating Loss</h3>**
#
# - We want to improve our model right??
# - So we calcuate the loss and then based on the loss we update the weights using backpropagation.
# - This loss is called as reconstruction error.
# - Mostly we use Squared error.
# \begin{equation} Loss(X,\hat{{X}})  = || X - \hat{{X}} ||^{{2}} \end{equation}

# %% [markdown]
# **<h3>Applications of Autoencoders</h3>**
#
# - Dimensionality reduction
# - Anomaly/outlier detection
# - Denoising
# - word embeddings
# - Text summarization

# %% [markdown]
# **<h3>Types</h3>**
#
# - Sparse autoencoder
# - Autoencoder
# - Convolutional autoencoder
# - Denoising
# - Sequence-to-sequence autoencoder
# - Variational autoenoder

# %% [markdown]
# **```
# Lets understand this with an example (Image reconstruction)
# ```**

# %% [markdown]
# **<h3> Deep AutoEncoder </h3>**

# %%
# Importing libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from sklearn.decomposition import PCA

# %%
# Load dataset 
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Convert to float32.
x_train, x_test = x_train.astype(np.float32), x_test.astype(np.float32)
# Flatten images to 1-D vector of 784 features (28*28).
x_train, x_test = x_train.reshape([-1, 784]), x_test.reshape([-1, 784])
# Normalize images value from [0, 255] to [0, 1].
x_train, x_test = x_train / 255., x_test / 255.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
# input placeholder
input_img = tf.keras.layers.Input(shape=(784,), name = "input")

# this is the encoded representation of the input
encoded = tf.keras.layers.Dense(128, activation='relu', name="emb_1")(input_img)
encoded = tf.keras.layers.Dense(64, activation='relu', name="emb_2")(encoded)
encoded = tf.keras.layers.Dense(16, activation='relu', name="emb_4")(encoded)
latent_vector = tf.keras.layers.Dense(2, activation='relu', name="latent_vector")(encoded)

# %%
# this is the loss reconstruction of the input
decoded = tf.keras.layers.Dense(16, activation='relu', name="dec_1")(latent_vector)
decoded = tf.keras.layers.Dense(64, activation='relu', name="dec_3")(decoded)
decoded = tf.keras.layers.Dense(128, activation='relu', name="dec_4")(decoded)
output_layer = tf.keras.layers.Dense(784, activation = 'sigmoid', name="output")(decoded)

# %%
# this model maps an input to its recommendation
autoencoder = tf.keras.models.Model(input_img, output_layer)

# %%
autoencoder.summary()
# Out:
# Model: "model_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 784)]             0
# _________________________________________________________________
# emb_1 (Dense)                (None, 128)               100480
# _________________________________________________________________
# emb_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# emb_4 (Dense)                (None, 16)                1040
# _________________________________________________________________
# latent_vector (Dense)        (None, 2)                 34
# _________________________________________________________________
# dec_1 (Dense)                (None, 16)                48
# _________________________________________________________________
# dec_3 (Dense)                (None, 64)                1088
# _________________________________________________________________
# dec_4 (Dense)                (None, 128)               8320
# _________________________________________________________________
# output (Dense)               (None, 784)               101136
# =================================================================
# Total params: 220,402
# Trainable params: 220,402
# Non-trainable params: 0
# _________________________________________________________________

# %%
# let's also create a seprate encoder model
# this mode maps an input to its encoded representation
encoder = tf.keras.models.Model(input_img, latent_vector)
encoder.summary()
# Out:
# Model: "model_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 784)]             0
# _________________________________________________________________
# emb_1 (Dense)                (None, 128)               100480
# _________________________________________________________________
# emb_2 (Dense)                (None, 64)                8256
# _________________________________________________________________
# emb_4 (Dense)                (None, 16)                1040
# _________________________________________________________________
# latent_vector (Dense)        (None, 2)                 34
# =================================================================
# Total params: 109,810
# Trainable params: 109,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Now let's train our autoencoder to reconstruct MNIST digits
autoencoder.compile(optimizer='adam', loss='mse')

# %%
# now let's train our autoencoder for 100 epochs
autoencoder.fit(x_train, x_train, epochs=100, batch_size=256, shuffle=True, validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0813 - val_loss: 0.0585
# Epoch 2/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0556 - val_loss: 0.0523
# Epoch 3/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0509 - val_loss: 0.0494
# Epoch 4/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0480 - val_loss: 0.0468
# Epoch 5/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0461 - val_loss: 0.0455
# Epoch 6/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0449 - val_loss: 0.0445
# Epoch 7/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0440 - val_loss: 0.0438
# Epoch 8/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0433 - val_loss: 0.0433
# Epoch 9/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0428 - val_loss: 0.0429
# Epoch 10/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0423
# Epoch 11/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0418 - val_loss: 0.0420
# Epoch 12/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0414 - val_loss: 0.0416
# Epoch 13/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0411 - val_loss: 0.0412
# Epoch 14/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0408 - val_loss: 0.0410
# Epoch 15/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0405 - val_loss: 0.0410
# Epoch 16/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0403 - val_loss: 0.0408
# Epoch 17/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0400 - val_loss: 0.0403
# Epoch 18/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0397 - val_loss: 0.0403
# Epoch 19/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0396 - val_loss: 0.0399
# Epoch 20/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0394 - val_loss: 0.0399
# Epoch 21/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0392 - val_loss: 0.0398
# Epoch 22/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0391 - val_loss: 0.0396
# Epoch 23/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0389 - val_loss: 0.0396
# Epoch 24/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0388 - val_loss: 0.0394
# Epoch 25/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0386 - val_loss: 0.0392
# Epoch 26/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0385 - val_loss: 0.0393
# Epoch 27/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0384 - val_loss: 0.0391
# Epoch 28/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0382 - val_loss: 0.0389
# Epoch 29/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0381 - val_loss: 0.0388
# Epoch 30/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0380 - val_loss: 0.0387
# Epoch 31/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0380 - val_loss: 0.0388
# Epoch 32/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0379 - val_loss: 0.0386
# Epoch 33/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0377 - val_loss: 0.0385
# Epoch 34/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0376 - val_loss: 0.0384
# Epoch 35/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0376 - val_loss: 0.0383
# Epoch 36/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0375 - val_loss: 0.0385
# Epoch 37/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0374 - val_loss: 0.0381
# Epoch 38/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0372 - val_loss: 0.0383
# Epoch 39/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0372 - val_loss: 0.0381
# Epoch 40/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0371 - val_loss: 0.0379
# Epoch 41/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0370 - val_loss: 0.0379
# Epoch 42/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0370 - val_loss: 0.0378
# Epoch 43/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0369 - val_loss: 0.0377
# Epoch 44/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0368 - val_loss: 0.0379
# Epoch 45/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0368 - val_loss: 0.0379
# Epoch 46/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0368 - val_loss: 0.0377
# Epoch 47/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0368 - val_loss: 0.0376
# Epoch 48/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0367 - val_loss: 0.0377
# Epoch 49/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0366 - val_loss: 0.0376
# Epoch 50/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0367 - val_loss: 0.0375
# Epoch 51/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0365 - val_loss: 0.0374
# Epoch 52/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0364 - val_loss: 0.0374
# Epoch 53/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0364 - val_loss: 0.0373
# Epoch 54/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0363 - val_loss: 0.0373
# Epoch 55/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0363 - val_loss: 0.0373
# Epoch 56/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0362 - val_loss: 0.0373
# Epoch 57/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0362 - val_loss: 0.0372
# Epoch 58/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0361 - val_loss: 0.0371
# Epoch 59/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0361 - val_loss: 0.0373
# Epoch 60/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0362 - val_loss: 0.0371
# Epoch 61/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0361 - val_loss: 0.0370
# Epoch 62/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.0371
# Epoch 63/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.0369
# Epoch 64/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0360 - val_loss: 0.0371
# Epoch 65/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0360 - val_loss: 0.0369
# Epoch 66/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.0368
# Epoch 67/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0359 - val_loss: 0.0368
# Epoch 68/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.0370
# Epoch 69/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.0370
# Epoch 70/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.0370
# Epoch 71/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.0368
# Epoch 72/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0357 - val_loss: 0.0367
# Epoch 73/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0358 - val_loss: 0.0369
# Epoch 74/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0357 - val_loss: 0.0366
# Epoch 75/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.0367
# Epoch 76/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0355 - val_loss: 0.0365
# Epoch 77/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0355 - val_loss: 0.0365
# Epoch 78/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0355 - val_loss: 0.0366
# Epoch 79/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0355 - val_loss: 0.0368
# Epoch 80/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0356 - val_loss: 0.0367
# Epoch 81/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0355 - val_loss: 0.0366
# Epoch 82/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0365
# Epoch 83/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0365
# Epoch 84/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0354 - val_loss: 0.0364
# Epoch 85/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.0363
# Epoch 86/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.0364
# Epoch 87/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0364
# Epoch 88/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0363
# Epoch 89/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.0364
# Epoch 90/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.0365
# Epoch 91/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0353 - val_loss: 0.0365
# Epoch 92/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0361
# Epoch 93/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0364
# Epoch 94/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0362
# Epoch 95/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0350 - val_loss: 0.0361
# Epoch 96/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0351 - val_loss: 0.0362
# Epoch 97/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0352 - val_loss: 0.0361
# Epoch 98/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0351 - val_loss: 0.0364
# Epoch 99/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0350 - val_loss: 0.0361
# Epoch 100/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0350 - val_loss: 0.0363

# %%
#encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-162c980dd275> in <module>()
# ----> 1 decoded_imgs = autoencoder.predict(x_test)
#
# NameError: name 'autoencoder' is not defined

# %%
n = 10 
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %%
# Dimensionality reduction with PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x_test)
principalDf = pd.DataFrame(data = principalComponents,columns = ['principal component 1', 'principal component 2'])
principalDf["label"] = y_test

# %%
pca.explained_variance_ratio_
# Out:
# array([0.10047699, 0.07544512], dtype=float32)

# %%
# Visualize
fig, ax = plt.subplots(figsize=(30,10))
plt.scatter(principalDf['principal component 1'], principalDf["principal component 2"],
            c=principalDf["label"], edgecolor='none', alpha=0.5,
            cmap="Accent")
plt.xlabel('principal component 1')
plt.ylabel('principal component 2')
plt.colorbar();

# %%
# Dimentionality reduction with encoder vector using PCA
principalComponents = encoder.predict(x_test)

#ca = PCA(n_components=2)
#principalComponents = pca.fit_transform(encoded_imgs)
principalDf = pd.DataFrame(data = list(principalComponents),columns = ['principal component 1', 'principal component 2'])
principalDf["label"] = y_test

# %%
pca.explained_variance_ratio_
# Out:
# array([0.10047699, 0.07544512], dtype=float32)

# %%
# Visualize
fig, ax = plt.subplots(figsize=(30,10))
plt.scatter(principalDf['principal component 1'], principalDf["principal component 2"],
            c=principalDf["label"], edgecolor='none', alpha=0.5,
            cmap="Accent")
plt.xlabel('principal component 1')
plt.ylabel('principal component 2')
plt.colorbar();

# %% [markdown]
# **<h3>Convolutional autoencoder</h3>**

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*uAeANQIOQPqWZnnuH-VEyw.jpeg" height="250"/>

# %% [markdown]
# **Kernel operation**
#
# <img src="https://miro.medium.com/max/1000/1*GcI7G-JLAQiEoCON7xFbhg.gif" height="250"/>

# %% [markdown]
# **Pooling layer**
#
# <img src="https://miro.medium.com/max/792/1*uoWYsCV5vBU8SHFPAPao-w.gif" height="250"/>

# %%
# Data

# Load dataset 
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Convert to float32.
x_train, x_test = x_train.astype(np.float32), x_test.astype(np.float32)
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
# Building encoder

input_img = tf.keras.layers.Input(shape=(28, 28, 1)) # adapt this if using `channels_first` image data format

x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# %%
# Building decoder 

x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# %%
# Building Autoencoder

autoencoder = tf.keras.models.Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.summary()
# Out:
# Model: "model_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_29 (InputLayer)        [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 7, 7, 8)           584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 8)           0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 28, 28, 1)         145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
autoencoder.fit(x_train, x_train, epochs=200, batch_size=128, shuffle=True, validation_data=(x_test, x_test)])
# Out:
# Epoch 1/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.6776 - val_loss: 0.6745
# Epoch 2/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.6696 - val_loss: 0.6638
# Epoch 3/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.6537 - val_loss: 0.6407
# Epoch 4/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.6140 - val_loss: 0.5768
# Epoch 5/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.5198 - val_loss: 0.4781
# Epoch 6/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.4605 - val_loss: 0.4539
# Epoch 7/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.4404 - val_loss: 0.4355
# Epoch 8/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.4224 - val_loss: 0.4177
# Epoch 9/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.4053 - val_loss: 0.4010
# Epoch 10/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.3893 - val_loss: 0.3854
# Epoch 11/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.3749 - val_loss: 0.3723
# Epoch 12/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.3633 - val_loss: 0.3615
# Epoch 13/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.3531 - val_loss: 0.3515
# Epoch 14/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.3434 - val_loss: 0.3417
# Epoch 15/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.3338 - val_loss: 0.3317
# Epoch 16/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.3240 - val_loss: 0.3214
# Epoch 17/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.3140 - val_loss: 0.3112
# Epoch 18/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.3041 - val_loss: 0.3013
# Epoch 19/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2949 - val_loss: 0.2924
# Epoch 20/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2868 - val_loss: 0.2847
# Epoch 21/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2799 - val_loss: 0.2781
# Epoch 22/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2737 - val_loss: 0.2721
# Epoch 23/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2680 - val_loss: 0.2668
# Epoch 24/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2635 - val_loss: 0.2629
# Epoch 25/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2600 - val_loss: 0.2597
# Epoch 26/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2571 - val_loss: 0.2569
# Epoch 27/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2545 - val_loss: 0.2545
# Epoch 28/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2523 - val_loss: 0.2523
# Epoch 29/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2503 - val_loss: 0.2504
# Epoch 30/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2484 - val_loss: 0.2486
# Epoch 31/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2468 - val_loss: 0.2470
# Epoch 32/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2452 - val_loss: 0.2454
# Epoch 33/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2438 - val_loss: 0.2440
# Epoch 34/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2424 - val_loss: 0.2427
# Epoch 35/200
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2411 - val_loss: 0.2414
# Epoch 36/200
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2399 - val_loss: 0.2402
# Epoch 37/200
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2387 - val_loss: 0.2391
# Epoch 38/200
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2376 - val_loss: 0.2380
# Epoch 39/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2366 - val_loss: 0.2369
# Epoch 40/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2355 - val_loss: 0.2359
# Epoch 41/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2345 - val_loss: 0.2349
# Epoch 42/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2336 - val_loss: 0.2339
# Epoch 43/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2326 - val_loss: 0.2330
# Epoch 44/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2317 - val_loss: 0.2321
# Epoch 45/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2308 - val_loss: 0.2312
# Epoch 46/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2299 - val_loss: 0.2303
# Epoch 47/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2291 - val_loss: 0.2295
# Epoch 48/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2282 - val_loss: 0.2287
# Epoch 49/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2274 - val_loss: 0.2278
# Epoch 50/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2266 - val_loss: 0.2271
# Epoch 51/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2259 - val_loss: 0.2263
# Epoch 52/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2251 - val_loss: 0.2255
# Epoch 53/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2244 - val_loss: 0.2248
# Epoch 54/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2237 - val_loss: 0.2241
# Epoch 55/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2230 - val_loss: 0.2234
# Epoch 56/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2223 - val_loss: 0.2227
# Epoch 57/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2216 - val_loss: 0.2220
# Epoch 58/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2209 - val_loss: 0.2214
# Epoch 59/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2203 - val_loss: 0.2207
# Epoch 60/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2196 - val_loss: 0.2200
# Epoch 61/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2190 - val_loss: 0.2194
# Epoch 62/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2184 - val_loss: 0.2188
# Epoch 63/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2178 - val_loss: 0.2182
# Epoch 64/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2172 - val_loss: 0.2176
# Epoch 65/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2166 - val_loss: 0.2170
# Epoch 66/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2160 - val_loss: 0.2164
# Epoch 67/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2154 - val_loss: 0.2158
# Epoch 68/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2149 - val_loss: 0.2152
# Epoch 69/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2143 - val_loss: 0.2147
# Epoch 70/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2138 - val_loss: 0.2141
# Epoch 71/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2132 - val_loss: 0.2136
# Epoch 72/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2127 - val_loss: 0.2130
# Epoch 73/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2122 - val_loss: 0.2125
# Epoch 74/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2117 - val_loss: 0.2120
# Epoch 75/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2112 - val_loss: 0.2115
# Epoch 76/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2107 - val_loss: 0.2110
# Epoch 77/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2102 - val_loss: 0.2105
# Epoch 78/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2097 - val_loss: 0.2100
# Epoch 79/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2093 - val_loss: 0.2096
# Epoch 80/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2088 - val_loss: 0.2091
# Epoch 81/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2083 - val_loss: 0.2086
# Epoch 82/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2079 - val_loss: 0.2082
# Epoch 83/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2074 - val_loss: 0.2077
# Epoch 84/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2070 - val_loss: 0.2073
# Epoch 85/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2066 - val_loss: 0.2069
# Epoch 86/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2062 - val_loss: 0.2064
# Epoch 87/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2058 - val_loss: 0.2060
# Epoch 88/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2053 - val_loss: 0.2056
# Epoch 89/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2049 - val_loss: 0.2052
# Epoch 90/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2045 - val_loss: 0.2048
# Epoch 91/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2041 - val_loss: 0.2044
# Epoch 92/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2037 - val_loss: 0.2040
# Epoch 93/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2034 - val_loss: 0.2036
# Epoch 94/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2030 - val_loss: 0.2032
# Epoch 95/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2026 - val_loss: 0.2028
# Epoch 96/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2023 - val_loss: 0.2025
# Epoch 97/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2019 - val_loss: 0.2021
# Epoch 98/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2015 - val_loss: 0.2017
# Epoch 99/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2012 - val_loss: 0.2014
# Epoch 100/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2008 - val_loss: 0.2010
# Epoch 101/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2005 - val_loss: 0.2007
# Epoch 102/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2001 - val_loss: 0.2003
# Epoch 103/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1998 - val_loss: 0.2000
# Epoch 104/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1995 - val_loss: 0.1996
# Epoch 105/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1992 - val_loss: 0.1993
# Epoch 106/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1988 - val_loss: 0.1990
# Epoch 107/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1985 - val_loss: 0.1986
# Epoch 108/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1982 - val_loss: 0.1983
# Epoch 109/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1979 - val_loss: 0.1980
# Epoch 110/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1976 - val_loss: 0.1977
# Epoch 111/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1973 - val_loss: 0.1973
# Epoch 112/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1970 - val_loss: 0.1970
# Epoch 113/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1967 - val_loss: 0.1967
# Epoch 114/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1964 - val_loss: 0.1964
# Epoch 115/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1961 - val_loss: 0.1961
# Epoch 116/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1958 - val_loss: 0.1958
# Epoch 117/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1955 - val_loss: 0.1955
# Epoch 118/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1952 - val_loss: 0.1953
# Epoch 119/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1950 - val_loss: 0.1950
# Epoch 120/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1947 - val_loss: 0.1947
# Epoch 121/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1944 - val_loss: 0.1944
# Epoch 122/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1941 - val_loss: 0.1941
# Epoch 123/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1939 - val_loss: 0.1939
# Epoch 124/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1936 - val_loss: 0.1936
# Epoch 125/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1934 - val_loss: 0.1933
# Epoch 126/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1931 - val_loss: 0.1930
# Epoch 127/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1928 - val_loss: 0.1928
# Epoch 128/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1926 - val_loss: 0.1925
# Epoch 129/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1923 - val_loss: 0.1923
# Epoch 130/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1921 - val_loss: 0.1920
# Epoch 131/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1919 - val_loss: 0.1918
# Epoch 132/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1916 - val_loss: 0.1915
# Epoch 133/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1914 - val_loss: 0.1913
# Epoch 134/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1912 - val_loss: 0.1910
# Epoch 135/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1909 - val_loss: 0.1908
# Epoch 136/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1907 - val_loss: 0.1906
# Epoch 137/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1905 - val_loss: 0.1903
# Epoch 138/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1902 - val_loss: 0.1901
# Epoch 139/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1900 - val_loss: 0.1899
# Epoch 140/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1898 - val_loss: 0.1896
# Epoch 141/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1896 - val_loss: 0.1894
# Epoch 142/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1894 - val_loss: 0.1892
# Epoch 143/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1891 - val_loss: 0.1890
# Epoch 144/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1889 - val_loss: 0.1887
# Epoch 145/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1887 - val_loss: 0.1885
# Epoch 146/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1885 - val_loss: 0.1883
# Epoch 147/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1883 - val_loss: 0.1881
# Epoch 148/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1881 - val_loss: 0.1879
# Epoch 149/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1879 - val_loss: 0.1877
# Epoch 150/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1877 - val_loss: 0.1874
# Epoch 151/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1875 - val_loss: 0.1872
# Epoch 152/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1873 - val_loss: 0.1870
# Epoch 153/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1871 - val_loss: 0.1868
# Epoch 154/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1869 - val_loss: 0.1866
# Epoch 155/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1867 - val_loss: 0.1864
# Epoch 156/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1865 - val_loss: 0.1862
# Epoch 157/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1863 - val_loss: 0.1860
# Epoch 158/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1861 - val_loss: 0.1858
# Epoch 159/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1859 - val_loss: 0.1856
# Epoch 160/200
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1857 - val_loss: 0.1855
# Epoch 161/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1856 - val_loss: 0.1853
# Epoch 162/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1854 - val_loss: 0.1851
# Epoch 163/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1852 - val_loss: 0.1849
# Epoch 164/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1850 - val_loss: 0.1847
# Epoch 165/200
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1848 - val_loss: 0.1845
# Epoch 166/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1847 - val_loss: 0.1843
# Epoch 167/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1845 - val_loss: 0.1841
# Epoch 168/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1843 - val_loss: 0.1840
# Epoch 169/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1841 - val_loss: 0.1838
# Epoch 170/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1840 - val_loss: 0.1836
# Epoch 171/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1838 - val_loss: 0.1834
# Epoch 172/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1836 - val_loss: 0.1832
# Epoch 173/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1834 - val_loss: 0.1831
# Epoch 174/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1833 - val_loss: 0.1829
# Epoch 175/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1831 - val_loss: 0.1827
# Epoch 176/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1829 - val_loss: 0.1825
# Epoch 177/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1828 - val_loss: 0.1824
# Epoch 178/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1826 - val_loss: 0.1822
# Epoch 179/200
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1824 - val_loss: 0.1820
# Epoch 180/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1823 - val_loss: 0.1819
# Epoch 181/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1821 - val_loss: 0.1817
# Epoch 182/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1820 - val_loss: 0.1815
# Epoch 183/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1818 - val_loss: 0.1814
# Epoch 184/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1816 - val_loss: 0.1812
# Epoch 185/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1815 - val_loss: 0.1810
# Epoch 186/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1813 - val_loss: 0.1809
# Epoch 187/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1812 - val_loss: 0.1807
# Epoch 188/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1810 - val_loss: 0.1806
# Epoch 189/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1809 - val_loss: 0.1804
# Epoch 190/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1807 - val_loss: 0.1802
# Epoch 191/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1806 - val_loss: 0.1801
# Epoch 192/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1804 - val_loss: 0.1799
# Epoch 193/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1803 - val_loss: 0.1798
# Epoch 194/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1801 - val_loss: 0.1796
# Epoch 195/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1800 - val_loss: 0.1795
# Epoch 196/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1798 - val_loss: 0.1793
# Epoch 197/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1797 - val_loss: 0.1792
# Epoch 198/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1795 - val_loss: 0.1790
# Epoch 199/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1794 - val_loss: 0.1789
# Epoch 200/200
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1793 - val_loss: 0.1787

# %%
# Visualize 
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
